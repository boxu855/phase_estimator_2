# %%
from Bio.PDB import *

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
protid = '6909_T338-R1'

parser = PDBParser()
structure = parser.get_structure("6909_T338-R1", "pdb/6909_T338-R1.pdb")

# %%
for chain in structure[0]:
    print(chain.id)
# Out:
# A

# %%
for chain in structure[0]:
    if chain.id == 'A':
        break

# %%
# all_atoms = []
# for atom in chain.get_atoms():
#     all_atoms.append(np.array(list(atom.get_vector())))
    
# X = np.array(all_atoms)
# np.savetxt('csv/all_atoms.csv', X, delimiter=',')

# %%
alpha_carbons = []
for atom in chain.get_atoms():
    if atom.id == 'CA':
        alpha_carbons.append(np.array(list(atom.get_vector())))
#     np.array(list(atom.get_vector()))
#     alpha_carbons.append()

# %%
X = np.array(alpha_carbons)
np.savetxt('csv/%s.csv'%protid, X, delimiter=',')

# %%
X.shape
# Out:
# (614, 3)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(X[:, 0], X[:, 1], zs = X[:, 2])

# %%
import nglview as nv

view = nv.show_biopython(structure)
view
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-9fd5b884c466> in <module>
# ----> 1 import nglview as nv
#       2
#       3 view = nv.show_biopython(structure)
#       4 view
#
# ModuleNotFoundError: No module named 'nglview'
